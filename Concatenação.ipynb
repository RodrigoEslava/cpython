# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoEslava/cpython/blob/main/Concatena%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Libraries/ Modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Open Data

# %%
data_2nd = pd.read_csv("embeddings_teste.txt", sep=" ", header= None)

second_df = pd.DataFrame(data=data_2nd)
second_df.columns=("Gene", '1','2','3','4','5')


data_1st = pd.read_csv("Decagon_ppi_sem_virgulas_com_index.txt", sep=" ")
first_df = pd.DataFrame(data=data_1st)
first_df.columns=('Gene_1', 'Gene_2')

first_df
# Out:
#         Gene_1  Gene_2
# 0       114787  375519
# 1       114787  285613
# 2       114787    7448
# 3       114787    4914
# 4       114787   51343
# ...        ...     ...
# 715606    5634    5636
# 715607    5635    5636
# 715608    5635    5631
# 715609    5636    5631
# 715610    8480    8487
#
# [715611 rows x 2 columns]

# %%
second_df
# Out:
#          Gene         1         2         3         4         5
# 0        8481  0.045649  0.815939  0.854348 -0.655166 -0.195375
# 1        3301  0.308905  1.150378  0.748331 -0.485905 -0.152400
# 2        8487 -0.017654  0.897601  0.410150 -1.447233 -0.802449
# 3        8484  2.704846  0.375412  0.955514 -0.367609 -0.068993
# 4        1295 -0.117250  0.634539  2.435030  0.139083  0.080239
# ...       ...       ...       ...       ...       ...       ...
# 19076   57348 -0.571863  1.174986  0.547623 -1.854035 -1.743249
# 19077  388595  1.158407  1.580999  0.519541 -0.490437  0.131811
# 19078  727866 -0.974044  0.671642  2.110115 -1.771468 -0.194473
# 19079   80206  0.182996  0.634144  0.617257 -0.219148 -1.163402
# 19080   84909  0.796155  0.711201  0.458408 -0.451549 -0.244309
#
# [19081 rows x 6 columns]

# %%
second_df.to_csv("second_df")

# %% [markdown]
# # Concatanate vectors positive samples
#
# ---

# %%
result = list()

classe = list()

for index, row in first_df.iterrows():

            first_column_from_2nd_df = second_df[second_df["Gene"].isin([row['Gene_1']])]
            

            second_column_from_2nd_df = second_df[second_df["Gene"].isin([row['Gene_2']])]

            third_column = (1)
            
            resulting_tuple = (first_column_from_2nd_df[["1","2","3","4","5"]].to_string(header = False, index=False), second_column_from_2nd_df[["1","2","3","4","5"]].to_string(header = False, index=False))

            classe.append(third_column)
           
            result.append(resulting_tuple)


first_df['concat'] = pd.Series(result)
first_df['classe'] = classe
first_df
# Out:
#         Gene_1  Gene_2                                             concat  \
# 0       114787  375519  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 1       114787  285613  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 2       114787    7448  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 3       114787    4914  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 4       114787   51343  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# ...        ...     ...                                                ...
# 715606    5634    5636  [0.881386 1.87614 0.730464 -1.401658 0.516512,...
# 715607    5635    5636  [0.362904 1.431055 0.935358 -1.285178 0.415917...
# 715608    5635    5631  [0.362904 1.431055 0.935358 -1.285178 0.415917...
# 715609    5636    5631  [0.651266 1.13983 1.068691 -0.838427 0.600965,...
# 715610    8480    8487  [-0.147213 0.844526 0.595591 -1.437492 -0.5858...
#
#        classe
# 0         [1]
# 1         [1]
# 2         [1]
# 3         [1]
# 4         [1]
# ...       ...
# 715606    [1]
# 715607    [1]
# 715608    [1]
# 715609    [1]
# 715610    [1]
#
# [715611 rows x 4 columns]

# %%
#first_df = pd.DataFrame(data = first_df)
first_df.to_csv(r"concatanate_positive_samples", header=None, index=None, sep=" ", mode="a")
first_df
# Out:
#         Gene_1  Gene_2                                             concat  \
# 0       114787  375519  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 1       114787  285613  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 2       114787    7448  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 3       114787    4914  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# 4       114787   51343  [0.778164 0.475622 0.715792 -0.251704 -0.15035...
# ...        ...     ...                                                ...
# 715606    5634    5636  [0.881386 1.87614 0.730464 -1.401658 0.516512,...
# 715607    5635    5636  [0.362904 1.431055 0.935358 -1.285178 0.415917...
# 715608    5635    5631  [0.362904 1.431055 0.935358 -1.285178 0.415917...
# 715609    5636    5631  [0.651266 1.13983 1.068691 -0.838427 0.600965,...
# 715610    8480    8487  [-0.147213 0.844526 0.595591 -1.437492 -0.5858...
#
#        classe
# 0         [1]
# 1         [1]
# 2         [1]
# 3         [1]
# 4         [1]
# ...       ...
# 715606    [1]
# 715607    [1]
# 715608    [1]
# 715609    [1]
# 715610    [1]
#
# [715611 rows x 4 columns]

# %%
df_1 = pd.read_csv("teste_exemplos_positivos.txt", header = None, sep = " ")
df_1 = pd.DataFrame(data = df_1)
df_1.dropna(axis = "columns")

# %%
df_1.to_csv("class_1_vectors.txt", header = None, index = None)

# %% [markdown]
# # Creating random entry

# %% [markdown]
# # Open data and creating list of genes

# %%
df_arestas = pd.read_csv(r"Decagon_ppi_sem_virgulas.txt", sep = " ", header = None)
df_arestas = pd.DataFrame(data = df_arestas)

split_df_0 = df_arestas[0]
split_df_1 = df_arestas[1]

lista_de_genes_duplicada = pd.concat([split_df_0,split_df_1])
lista_de_genes = lista_de_genes_duplicada.drop_duplicates()

lista_de_genes = pd.DataFrame(data = lista_de_genes)
lista_de_genes
# Out:
#              0
# 0       114787
# 18      114786
# 21      114785
# 47      114784
# 52      114783
# ...        ...
# 705095   65121
# 706959  728911
# 707331  728072
# 710291   10990
# 714852  440955
#
# [19081 rows x 1 columns]

# %%
lista_de_genes.to_csv(r"lista_de_genes", header=None, index=None, sep=" ", mode="a")

# %% [markdown]
# # Creating Random Graph

# %%
np.random.seed(0)

#lista_de_genes = pd.DataFrame(data = lista_de_genes)
lista_randomica = []

for i in range(718600):

  
  
  first_column = lista_de_genes.sample()
 
          
  second_column = lista_de_genes.sample()
            
  resulting_list = [first_column.to_string(header = False, index = False), second_column.to_string(header = False , index = False)]
  
  lista_randomica.append(resulting_list)

lista_randomica = pd.DataFrame(data = lista_randomica )
lista_randomica
# Out:
#              0       1
# 0       339488   54507
# 1         8737    4162
# 2        85450   10744
# 3         9411    2027
# 4        90701  257000
# ...        ...     ...
# 718595   26073   27136
# 718596    7307   27445
# 718597  121506   55863
# 718598   26824   63982
# 718599   56624    4242
#
# [718600 rows x 2 columns]

# %%
lista_randomica
# Out:
#              0       1
# 0        50604    6097
# 1       132954    1739
# 2         5143    1788
# 3        91750    5066
# 4         6634   56652
# ...        ...     ...
# 717995   51065    4908
# 717996   55063  390199
# 717997  259266    4815
# 717998  168002   51715
# 717999    3290  133418
#
# [718000 rows x 2 columns]

# %%
lista_randomica.to_csv("lista_randomica.txt", header=None, index=None, sep=" ", mode="a")
lista_randomica
# Out:
#              0       1
# 0       339488   54507
# 1         8737    4162
# 2        85450   10744
# 3         9411    2027
# 4        90701  257000
# ...        ...     ...
# 718595   26073   27136
# 718596    7307   27445
# 718597  121506   55863
# 718598   26824   63982
# 718599   56624    4242
#
# [718600 rows x 2 columns]

# %%
lista_randomica = pd.read_csv("lista_randomica.txt", header=None, sep=" ")
lista_randomica
# Out:
#              0       1
# 0       339488   54507
# 1         8737    4162
# 2        85450   10744
# 3         9411    2027
# 4        90701  257000
# ...        ...     ...
# 718595   26073   27136
# 718596    7307   27445
# 718597  121506   55863
# 718598   26824   63982
# 718599   56624    4242
#
# [718600 rows x 2 columns]

# %%
lista_ran_sem_dupli = lista_randomica.drop_duplicates()
lista_ran_sem_dupli
# Out:
#              0       1
# 0       339488   54507
# 1         8737    4162
# 2        85450   10744
# 3         9411    2027
# 4        90701  257000
# ...        ...     ...
# 718595   26073   27136
# 718596    7307   27445
# 718597  121506   55863
# 718598   26824   63982
# 718599   56624    4242
#
# [717904 rows x 2 columns]

# %%
lista_ran_sem_dupli["soma_colunas"] = lista_ran_sem_dupli[0] + lista_ran_sem_dupli[1]
lista_ran_sem_dupli["multiplicação_colunas"] = lista_ran_sem_dupli[0] * lista_ran_sem_dupli[1]

lista_ran_sem_dupli["primeira_coluna^2"] = lista_ran_sem_dupli[0] * lista_ran_sem_dupli[0]

lista_ran_sem_dupli["subtração_col_^2_col_multiplicação"] = lista_ran_sem_dupli["primeira_coluna^2"] - lista_ran_sem_dupli["multiplicação_colunas"]

lista_ran_sem_dupli["soma_soma_col_multiplicação"] = lista_ran_sem_dupli["soma_colunas"] + lista_ran_sem_dupli["multiplicação_colunas"]
# Out:
# <ipython-input-87-81034096f90f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_ran_sem_dupli["soma_colunas"] = lista_ran_sem_dupli[0] + lista_ran_sem_dupli[1]
# <ipython-input-87-81034096f90f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_ran_sem_dupli["multiplicação_colunas"] = lista_ran_sem_dupli[0] * lista_ran_sem_dupli[1]
# <ipython-input-87-81034096f90f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_ran_sem_dupli["primeira_coluna^2"] = lista_ran_sem_dupli[0] * lista_ran_sem_dupli[0]
# <ipython-input-87-81034096f90f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_ran_sem_dupli["subtração_col_^2_col_multiplicação"] = lista_ran_sem_dupli["primeira_coluna^2"] - lista_ran_sem_dupli["multiplicação_colunas"]
# <ipython-input-87-81034096f90f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lista_ran_sem_dupli["soma_soma_col_multiplicação"] = lista_ran_sem_dupli["soma_colunas"] + lista_ran_sem_dupli["multiplicação_colunas"]

# %%
l_r_s_d_m = lista_ran_sem_dupli.drop_duplicates(subset = ["soma_soma_col_multiplicação"])
l_r_s_d_m
# Out:
#              0       1  soma_colunas  multiplicação_colunas  \
# 0       339488   54507        393995            18504472416
# 1         8737    4162         12899               36363394
# 2        85450   10744         96194              918074800
# 3         9411    2027         11438               19076097
# 4        90701  257000        347701            23310157000
# ...        ...     ...           ...                    ...
# 718595   26073   27136         53209              707516928
# 718596    7307   27445         34752              200540615
# 718597  121506   55863        177369             6787689678
# 718598   26824   63982         90806             1716253168
# 718599   56624    4242         60866              240199008
#
#         primeira_coluna^2  subtração_col_^2_col_multiplicação  \
# 0            115252102144                         96747629728
# 1                76335169                            39971775
# 2              7301702500                          6383627700
# 3                88566921                            69490824
# 4              8226671401                        -15083485599
# ...                   ...                                 ...
# 718595          679801329                           -27715599
# 718596           53392249                          -147148366
# 718597        14763708036                          7976018358
# 718598          719526976                          -996726192
# 718599         3206277376                          2966078368
#
#         soma_soma_col_multiplicação
# 0                       18504866411
# 1                          36376293
# 2                         918170994
# 3                          19087535
# 4                       23310504701
# ...                             ...
# 718595                    707570137
# 718596                    200575367
# 718597                   6787867047
# 718598                   1716343974
# 718599                    240259874
#
# [716306 rows x 7 columns]

# %%
l_r_s_d_s = l_r_s_d_m[l_r_s_d_m['subtração_col_^2_col_multiplicação'] != 0]

l_r_s_d_s = pd.DataFrame(data = l_r_s_d_s)

l_r_s_d_s
# Out:
#              0       1  soma_colunas  multiplicação_colunas  \
# 0       339488   54507        393995            18504472416
# 1         8737    4162         12899               36363394
# 2        85450   10744         96194              918074800
# 3         9411    2027         11438               19076097
# 4        90701  257000        347701            23310157000
# ...        ...     ...           ...                    ...
# 718595   26073   27136         53209              707516928
# 718596    7307   27445         34752              200540615
# 718597  121506   55863        177369             6787689678
# 718598   26824   63982         90806             1716253168
# 718599   56624    4242         60866              240199008
#
#         primeira_coluna^2  subtração_col_^2_col_multiplicação  \
# 0            115252102144                         96747629728
# 1                76335169                            39971775
# 2              7301702500                          6383627700
# 3                88566921                            69490824
# 4              8226671401                        -15083485599
# ...                   ...                                 ...
# 718595          679801329                           -27715599
# 718596           53392249                          -147148366
# 718597        14763708036                          7976018358
# 718598          719526976                          -996726192
# 718599         3206277376                          2966078368
#
#         soma_soma_col_multiplicação
# 0                       18504866411
# 1                          36376293
# 2                         918170994
# 3                          19087535
# 4                       23310504701
# ...                             ...
# 718595                    707570137
# 718596                    200575367
# 718597                   6787867047
# 718598                   1716343974
# 718599                    240259874
#
# [716261 rows x 7 columns]

# %%
arestas_randomicas = []
arestas_randomicas = pd.DataFrame(data = arestas_randomicas, columns = [0,1])
arestas_randomicas[0] = l_r_s_d_s[0]
arestas_randomicas[1] = l_r_s_d_s[1]

arestas_randomicas
# Out:
#              0       1
# 0       339488   54507
# 1         8737    4162
# 2        85450   10744
# 3         9411    2027
# 4        90701  257000
# ...        ...     ...
# 718595   26073   27136
# 718596    7307   27445
# 718597  121506   55863
# 718598   26824   63982
# 718599   56624    4242
#
# [716261 rows x 2 columns]

# %%
arestas_randomicas.to_csv(r"arestas_randomicas.txt", header = None, index = None, sep = " ")

# %% [markdown]
# # Concatenate Vectors Negative Samples

# %% [markdown]
# # Open Data

# %%
data_1st = pd.read_csv("arestas_randomicas.txt", sep=" ")
first_df = pd.DataFrame(data=data_1st)
first_df.columns=('Gene_1', 'Gene_2')

data_2nd = pd.read_csv("embeddings_teste.txt", sep=" ", header= None)
second_df = pd.DataFrame(data=data_2nd)
second_df.columns=("Gene", '1','2','3','4','5')


data_3st = pd.read_csv("Decagon_ppi_sem_virgulas_com_index.txt", sep=" ")
third_df = pd.DataFrame(data = data_3st)
third_df.columns=('Gene_1', 'Gene_2')

first_df
# Out:
#         Gene_1  Gene_2
# 0         8737    4162
# 1        85450   10744
# 2         9411    2027
# 3        90701  257000
# 4         2046   11093
# ...        ...     ...
# 716255   26073   27136
# 716256    7307   27445
# 716257  121506   55863
# 716258   26824   63982
# 716259   56624    4242
#
# [716260 rows x 2 columns]

# %%
second_df
# Out:
#          Gene         1         2         3         4         5
# 0        8481  0.045649  0.815939  0.854348 -0.655166 -0.195375
# 1        3301  0.308905  1.150378  0.748331 -0.485905 -0.152400
# 2        8487 -0.017654  0.897601  0.410150 -1.447233 -0.802449
# 3        8484  2.704846  0.375412  0.955514 -0.367609 -0.068993
# 4        1295 -0.117250  0.634539  2.435030  0.139083  0.080239
# ...       ...       ...       ...       ...       ...       ...
# 19076   57348 -0.571863  1.174986  0.547623 -1.854035 -1.743249
# 19077  388595  1.158407  1.580999  0.519541 -0.490437  0.131811
# 19078  727866 -0.974044  0.671642  2.110115 -1.771468 -0.194473
# 19079   80206  0.182996  0.634144  0.617257 -0.219148 -1.163402
# 19080   84909  0.796155  0.711201  0.458408 -0.451549 -0.244309
#
# [19081 rows x 6 columns]

# %%
third_df
# Out:
#         Gene_1  Gene_2
# 0       114787  375519
# 1       114787  285613
# 2       114787    7448
# 3       114787    4914
# 4       114787   51343
# ...        ...     ...
# 715606    5634    5636
# 715607    5635    5636
# 715608    5635    5631
# 715609    5636    5631
# 715610    8480    8487
#
# [715611 rows x 2 columns]

# %% [markdown]
# # Check duplicate rows in all datasets of arestas

# %%
arestas_totais = pd.concat([third_df,first_df])
arestas_totais
# Out:
#         Gene_1  Gene_2
# 0       114787  375519
# 1       114787  285613
# 2       114787    7448
# 3       114787    4914
# 4       114787   51343
# ...        ...     ...
# 716255   26073   27136
# 716256    7307   27445
# 716257  121506   55863
# 716258   26824   63982
# 716259   56624    4242
#
# [1431871 rows x 2 columns]

# %%
teste = pd.read_csv("teste_gpt.txt", sep=" ")
teste = pd.DataFrame(data=teste)
teste.columns=('Gene_1', 'Gene_2')
teste

# %%
#delete reverse rows
#teste = teste.apply(lambda x: sorted(x), axis=1)
arestas_totais = arestas_totais.apply(lambda x: sorted(x), axis=1)

arestas_totais = arestas_totais.drop_duplicates()

#teste = teste.drop_duplicates()
arestas_totais
teste

# %%
arestas_totais.loc[[715610]]

# %%
#fit the range of the data

drop_rows = list(range(715611,716260))

first_df.drop(index = first_df.iloc[drop_rows]. index.tolist(), inplace = True)

# %%
first_df
# Out:
#         Gene_1  Gene_2
# 0         8737    4162
# 1        85450   10744
# 2         9411    2027
# 3        90701  257000
# 4         2046   11093
# ...        ...     ...
# 715606   90737  339855
# 715607     310    4325
# 715608    6585    8079
# 715609    4881   63899
# 715610   55556    8226
#
# [715611 rows x 2 columns]

# %%
result = list()

classe = list()

for index, row in first_df.iterrows():

            first_column_from_2nd_df = second_df[second_df["Gene"].isin([row['Gene_1']])]
            

            second_column_from_2nd_df = second_df[second_df["Gene"].isin([row['Gene_2']])]

            third_column = (0)
            
            resulting_tuple = (first_column_from_2nd_df[["1","2","3","4","5"]].to_string(header = False, index=False), second_column_from_2nd_df[["1","2","3","4","5"]].to_string(header = False, index=False))

            classe.append(third_column)
           
            result.append(resulting_tuple)


first_df['concat'] = pd.Series(result)
first_df['classe'] = classe
first_df
# Out:
#         Gene_1  Gene_2                                             concat  \
# 0         8737    4162  (0.227824 0.111845 0.915019 -0.225481 -0.71403...
# 1        85450   10744  (0.810568 0.462844 1.805829 0.941257 -0.56275,...
# 2         9411    2027  (0.147368 0.181856 1.210494 -0.781029 -0.00346...
# 3        90701  257000  (1.331824 1.552839 -0.055379 -0.544017 -0.7889...
# 4         2046   11093  (0.553483 -0.110436 1.490447 -0.450007 0.07933...
# ...        ...     ...                                                ...
# 715606   90737  339855  (0.20075 0.274724 0.62451 -0.899938 -0.511145,...
# 715607     310    4325  (0.155255 0.308197 0.719711 -0.669243 -0.47317...
# 715608    6585    8079  (0.513246 0.24714 2.436578 -0.277446 0.693172,...
# 715609    4881   63899  (1.374483 0.561892 0.210898 -0.872078 -0.15180...
# 715610   55556    8226  (2.373171 1.818255 1.237502 -0.562256 0.822018...
#
#         classe
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 715606       0
# 715607       0
# 715608       0
# 715609       0
# 715610       0
#
# [715611 rows x 4 columns]

# %%
first_df
# Out:
#         Gene_1  Gene_2                                             concat  \
# 0         8737    4162  (0.227824 0.111845 0.915019 -0.225481 -0.71403...
# 1        85450   10744  (0.810568 0.462844 1.805829 0.941257 -0.56275,...
# 2         9411    2027  (0.147368 0.181856 1.210494 -0.781029 -0.00346...
# 3        90701  257000  (1.331824 1.552839 -0.055379 -0.544017 -0.7889...
# 4         2046   11093  (0.553483 -0.110436 1.490447 -0.450007 0.07933...
# ...        ...     ...                                                ...
# 715606   90737  339855  (0.20075 0.274724 0.62451 -0.899938 -0.511145,...
# 715607     310    4325  (0.155255 0.308197 0.719711 -0.669243 -0.47317...
# 715608    6585    8079  (0.513246 0.24714 2.436578 -0.277446 0.693172,...
# 715609    4881   63899  (1.374483 0.561892 0.210898 -0.872078 -0.15180...
# 715610   55556    8226  (2.373171 1.818255 1.237502 -0.562256 0.822018...
#
#         classe
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 715606       0
# 715607       0
# 715608       0
# 715609       0
# 715610       0
#
# [715611 rows x 4 columns]

# %%
first_df.to_csv("negative_samples.txt", header = None, index = None)

# %%
df_n = pd.read_csv("negative_samples.txt", header = None, sep = " ")
df_n = pd.DataFrame(data = df_n)
df_n.dropna(axis = "columns", inplace = True)
df_n
# Out:
#            0       1         3         4         5         6         7   \
# 0        8737    4162  0.227824  0.111845  0.915019 -0.225481 -0.714039
# 1       85450   10744  0.810568  0.462844  1.805829  0.941257 -0.562750
# 2        9411    2027  0.147368  0.181856  1.210494 -0.781029 -0.003462
# 3       90701  257000  1.331824  1.552839 -0.055379 -0.544017 -0.788973
# 4        2046   11093  0.553483 -0.110436  1.490447 -0.450007  0.079332
# ...       ...     ...       ...       ...       ...       ...       ...
# 715606  90737  339855  0.200750  0.274724  0.624510 -0.899938 -0.511145
# 715607    310    4325  0.155255  0.308197  0.719711 -0.669243 -0.473170
# 715608   6585    8079  0.513246  0.247140  2.436578 -0.277446  0.693172
# 715609   4881   63899  1.374483  0.561892  0.210898 -0.872078 -0.151804
# 715610  55556    8226  2.373171  1.818255  1.237502 -0.562256  0.822018
#
#               9         10        11        12        13  15
# 0       0.653379  0.498316  0.792746 -0.025925 -0.428536   0
# 1      -0.716941 -0.141307  1.532952 -1.071206 -1.925726   0
# 2       0.562065  1.139772  0.485890 -0.601794 -0.241325   0
# 3      -0.157889  0.556150  0.628204 -0.811924 -0.972130   0
# 4       2.160419  0.477013  2.675196  1.710217 -1.625894   0
# ...          ...       ...       ...       ...       ...  ..
# 715606  0.749858  0.652715  1.418007 -1.384832  0.797590   0
# 715607  1.183004 -0.403156  1.681676  0.731652 -1.112852   0
# 715608 -0.133098  0.461254  0.817654 -0.528891 -0.963959   0
# 715609  0.797217  1.371346 -0.179053 -1.365025 -1.160668   0
# 715610  0.588964  2.098053  1.497819 -1.468737  0.985457   0
#
# [715611 rows x 13 columns]

# %%
df_n.to_csv("class_0_vectors.txt", header = None, index = None)

# %%
df_p = pd.read_csv("class_1_vectors.txt", header = None, sep = ",")
df_p = pd.DataFrame(data = df_p)



df_n = pd.read_csv("class_0_vectors.txt", header = None, sep = ",")
df_n = pd.DataFrame(data = df_n)
df_n.dropna(axis = "columns")


df_p
# Out:
#             0       1         2         3         4         5         6   \
# 0       114787  375519  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 1       114787  285613  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 2       114787    7448  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 3       114787    4914  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 4       114787   51343  0.778164  0.475622  0.715792 -0.251704 -0.150356
# ...        ...     ...       ...       ...       ...       ...       ...
# 715606    5634    5636  0.881386  1.876140  0.730464 -1.401658  0.516512
# 715607    5635    5636  0.362904  1.431055  0.935358 -1.285178  0.415917
# 715608    5635    5631  0.362904  1.431055  0.935358 -1.285178  0.415917
# 715609    5636    5631  0.651266  1.139830  1.068691 -0.838427  0.600965
# 715610    8480    8487 -0.147213  0.844526  0.595591 -1.437492 -0.585847
#
#               7         8         9         10        11  12
# 0       0.679890  0.202166  1.085294 -0.354643  0.080082   1
# 1       0.307974  0.250093  1.434479  0.158018 -0.232124   1
# 2       0.514870  0.199525  0.751447 -0.191767 -0.486657   1
# 3       0.014077  0.967554  0.793498 -0.690786 -0.263792   1
# 4       0.103214  0.444202  0.831132 -0.484471 -0.458331   1
# ...          ...       ...       ...       ...       ...  ..
# 715606  0.651266  1.139830  1.068691 -0.838427  0.600965   1
# 715607  0.651266  1.139830  1.068691 -0.838427  0.600965   1
# 715608  0.486600  0.927690  0.996919 -0.807010  0.373347   1
# 715609  0.486600  0.927690  0.996919 -0.807010  0.373347   1
# 715610 -0.017654  0.897601  0.410150 -1.447233 -0.802449   1
#
# [715611 rows x 13 columns]

# %%
df_n
# Out:
#            0       1         2         3         4         5         6   \
# 0        8737    4162  0.227824  0.111845  0.915019 -0.225481 -0.714039
# 1       85450   10744  0.810568  0.462844  1.805829  0.941257 -0.562750
# 2        9411    2027  0.147368  0.181856  1.210494 -0.781029 -0.003462
# 3       90701  257000  1.331824  1.552839 -0.055379 -0.544017 -0.788973
# 4        2046   11093  0.553483 -0.110436  1.490447 -0.450007  0.079332
# ...       ...     ...       ...       ...       ...       ...       ...
# 715606  90737  339855  0.200750  0.274724  0.624510 -0.899938 -0.511145
# 715607    310    4325  0.155255  0.308197  0.719711 -0.669243 -0.473170
# 715608   6585    8079  0.513246  0.247140  2.436578 -0.277446  0.693172
# 715609   4881   63899  1.374483  0.561892  0.210898 -0.872078 -0.151804
# 715610  55556    8226  2.373171  1.818255  1.237502 -0.562256  0.822018
#
#               7         8         9         10        11  12
# 0       0.653379  0.498316  0.792746 -0.025925 -0.428536   0
# 1      -0.716941 -0.141307  1.532952 -1.071206 -1.925726   0
# 2       0.562065  1.139772  0.485890 -0.601794 -0.241325   0
# 3      -0.157889  0.556150  0.628204 -0.811924 -0.972130   0
# 4       2.160419  0.477013  2.675196  1.710217 -1.625894   0
# ...          ...       ...       ...       ...       ...  ..
# 715606  0.749858  0.652715  1.418007 -1.384832  0.797590   0
# 715607  1.183004 -0.403156  1.681676  0.731652 -1.112852   0
# 715608 -0.133098  0.461254  0.817654 -0.528891 -0.963959   0
# 715609  0.797217  1.371346 -0.179053 -1.365025 -1.160668   0
# 715610  0.588964  2.098053  1.497819 -1.468737  0.985457   0
#
# [715611 rows x 13 columns]

# %%
vectors_input_ml = []

vectors_input_ml = pd.DataFrame(data  = vectors_input_ml)

vectors_input_ml = pd.concat([df_p, df_n])

vectors_input_ml
# Out:
#             0       1         2         3         4         5         6   \
# 0       114787  375519  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 1       114787  285613  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 2       114787    7448  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 3       114787    4914  0.778164  0.475622  0.715792 -0.251704 -0.150356
# 4       114787   51343  0.778164  0.475622  0.715792 -0.251704 -0.150356
# ...        ...     ...       ...       ...       ...       ...       ...
# 715606   90737  339855  0.200750  0.274724  0.624510 -0.899938 -0.511145
# 715607     310    4325  0.155255  0.308197  0.719711 -0.669243 -0.473170
# 715608    6585    8079  0.513246  0.247140  2.436578 -0.277446  0.693172
# 715609    4881   63899  1.374483  0.561892  0.210898 -0.872078 -0.151804
# 715610   55556    8226  2.373171  1.818255  1.237502 -0.562256  0.822018
#
#               7         8         9         10        11  12
# 0       0.679890  0.202166  1.085294 -0.354643  0.080082   1
# 1       0.307974  0.250093  1.434479  0.158018 -0.232124   1
# 2       0.514870  0.199525  0.751447 -0.191767 -0.486657   1
# 3       0.014077  0.967554  0.793498 -0.690786 -0.263792   1
# 4       0.103214  0.444202  0.831132 -0.484471 -0.458331   1
# ...          ...       ...       ...       ...       ...  ..
# 715606  0.749858  0.652715  1.418007 -1.384832  0.797590   0
# 715607  1.183004 -0.403156  1.681676  0.731652 -1.112852   0
# 715608 -0.133098  0.461254  0.817654 -0.528891 -0.963959   0
# 715609  0.797217  1.371346 -0.179053 -1.365025 -1.160668   0
# 715610  0.588964  2.098053  1.497819 -1.468737  0.985457   0
#
# [1431222 rows x 13 columns]

# %%
vectors_input_ml.to_csv("vectors_input_ml.txt", header = None, index = None, sep = " ")
